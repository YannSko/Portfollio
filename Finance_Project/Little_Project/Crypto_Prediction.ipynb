# %%
import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta
today = date.today()

d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days=730)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

data = yf.download('BTC-USD', 
                      start=start_date, 
                      end=end_date, 
                      progress=False)
data["Date"] = data.index
data = data[["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]]
data.reset_index(drop=True, inplace=True)
print(data.head())

# %%
data.shape

# %% [markdown]
#  Now let’s visualize the change in bitcoin prices till today by using a candlestick chart:

# %%
import plotly.graph_objects as go
figure = go.Figure(data=[go.Candlestick(x=data["Date"],
                                        open=data["Open"], 
                                        high=data["High"],
                                        low=data["Low"], 
                                        close=data["Close"])])
figure.update_layout(title = "Bitcoin Price Analysis", 
                     xaxis_rangeslider_visible=False)
figure.show()

# %% [markdown]
# The Close column in the dataset contains the values we need to predict. So, let’s have a look at the correlation of all the columns in the data concerning the Close column:

# %%
correlation = data.corr()
print(correlation["Close"].sort_values(ascending=False))

# %% [markdown]
# Predicting  future prices of cryptocurrency is based on the problem of Time series analysis.
#  The AutoTS library in Python is one of  libraries i found  for time series analysis.

# %%
from autots import AutoTS
model = AutoTS(forecast_length=30, frequency='infer', ensemble='simple')
model = model.fit(data, date_col='Date', value_col='Close', id_col=None)
prediction = model.predict()
forecast = prediction.forecast
print(forecast)
# Out:
# 87 - ARIMA with avg smape 50.44:
# Model Number: 88 of 188 with model ARIMA for Validation 3
# Model Number: 89 of 188 with model MultivariateMotif for Validation 3
# 89 - MultivariateMotif with avg smape 13.73:
# Model Number: 90 of 188 with model MultivariateMotif for Validation 3
# 90 - MultivariateMotif with avg smape 13.73:
# Model Number: 91 of 188 with model MultivariateMotif for Validation 3
# 91 - MultivariateMotif with avg smape 15.12:
# Model Number: 92 of 188 with model ETS for Validation 3
# 92 - ETS with avg smape 18.25:
# Model Number: 93 of 188 with model UnobservedComponents for Validation 3
# 93 - UnobservedComponents with avg smape 17.54:
# Model Number: 94 of 188 with model MultivariateMotif for Validation 3
# 94 - MultivariateMotif with avg smape 13.66:
# Model Number: 95 of 188 with model SeasonalNaive for Validation 3
# 95 - SeasonalNaive with avg smape 17.41:
# Model Number: 96 of 188 with model MultivariateMotif for Validation 3
# ...
